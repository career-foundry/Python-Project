# %% [markdown]
# #   Importing libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #  Paths

# %%
path = '/Users/wehadiwood/Desktop/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/wehadiwood/Desktop/Instacart Basket Analysis'

# %% [markdown]
# # Importing Data

# %%
import pandas as pd
import os

# %%
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'orders_products_combined.pkl'))

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = 0)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
orders_products_combined.shape
# Out:
# (32434489, 11)

# %% [markdown]
# # Understand the basic information of the dataframes

# %%
orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# # Merging dataframe

# %% [raw]
# Evaluation: The column 'product_id' is a common key between the two dataframes, indicating that a merge is feasible. The type of merge to apply depends on the desired outcome of the final dataframe. In this case, since we are only interested in information that exists in both dataframes, an inner merge is the most appropriate choice, as it retains only the matching records from both sides.

# %%
pd.merge(orders_products_combined , df_prods , on = ['product_id'] , how = 'inner', indicator = 'match' )
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434207   2977660   206209    prior            13          1
# 32434208   2977660   206209    prior            13          1
# 32434209   2977660   206209    prior            13          1
# 32434210   2977660   206209    prior            13          1
# 32434211   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %% [raw]
# Evaluation: In the previous merge operation, a 'merge' column was created as a merge indicator. However, this column is not relevant for the new merge between orders_products_combined and df_prods. To improve the clarity and presentation of the final dataframe, the 'merge' column from the earlier merge should be dropped after completing the new merge.

# %%
ords_prods_merge = orders_products_combined.merge(df_prods , on = ['product_id'] , indicator = 'match' )

# %%
ords_prods_merge.drop('_merge', axis = 1 )
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434207   2977660   206209    prior            13          1
# 32434208   2977660   206209    prior            13          1
# 32434209   2977660   206209    prior            13          1
# 32434210   2977660   206209    prior            13          1
# 32434211   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
orders_products_combined.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))
